# %%
import matplotlib

# %%
matplotlib.__version__
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 matplotlib.__version__
#
# NameError: name 'matplotlib' is not defined

# %%
 from import matplotlib
# Out:
#   Cell In[5], line 1
#     from import matplotlib
#          ^
# SyntaxError: invalid syntax

# %%
matplotlib.__version__
# Out:
# '3.8.0'

# %%
from matplotlib import
pyplot as plt
plt.plot([1,2,6],[4,5,6])
ply.show()
# Out:
#   Cell In[4], line 1
#     from matplotlib import
#                           ^
# SyntaxError: invalid syntax

# %%
from matplotlib import pyplot as plt
plt.plot([1,2,6],[4,5,6])
plt.show()

# %%
from matplotlib import
x=[3,6,7]
y=[4,10,9]
plt.plot(x,y)
plt.title('line graph')
plt.ylabel('y axis')
plt.xlabel('x axis')
plt.show()
# Out:
#   Cell In[1], line 1
#     from matplotlib import
#                           ^
# SyntaxError: invalid syntax

# %%
x=[3,6,7]
y=[4,10,9]
plt.plot(x,y)
plt.title('line graph')
plt.ylabel('y axis')
plt.xlabel('x axis')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 3
#       1 x=[3,6,7]
#       2 y=[4,10,9]
# ----> 3 plt.plot(x,y)
#       4 plt.title('line graph')
#       5 plt.ylabel('y axis')
#
# NameError: name 'plt' is not defined

# %%
x=[3,6,7]
y=[4,10,9]
plt.plot(x,y)
plt.title('line graph')
plt.ylabel('y axis')
plt.xlabel('x axis')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 3
#       1 x=[3,6,7]
#       2 y=[4,10,9]
# ----> 3 plt.plot(x,y)
#       4 plt.title('line graph')
#       5 plt.ylabel('y axis')
#
# NameError: name 'plt' is not defined

# %%
import numpy as np
import matplotlib.pyplot as plt
fig=plt.figure(figsize(2,2))
ax=plt.axes()
x=np.linspace(0,10,1000)
ax.plot(x,np.sin(x))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 3
#       1 import numpy as np
#       2 import matplotlib.pyplot as plt
# ----> 3 fig=plt.figure(figsize(2,2))
#       4 ax=plt.axes()
#       5 x=np.linspace(0,10,1000)
#
# NameError: name 'figsize' is not defined

# %%
import numpy as np
import matplotlib.pyplot as plt
fig=plt.figure(figsize=(10,2))
ax=plt.axes()
x=np.linspace(0,10,1000)
ax.plot(x,np.sin(x))

# %%
import matplotlib.pyplot as plt
x=[10,20,30,40,50]
y=[29,10,20,39,33]
plt.xlabel('overs')
plt.ylabel('runs scored')
plt.title('over wise runs scored\n inida vs england')
plt.plot(x,y,'b',linewidth=4,linestyle='dashed')
plt.show()

# %%
import matplotlib.pyplot as plt
x=[10,20,30,40,50]
y=[29,10,20,39,33]
plt.xlabel('overs')
plt.ylabel('runs scored')
plt.title('over wise runs scored\n inida vs england')
plt.plot(x,y,'r',linewidth=4,linestyle='dashed')
plt.show()

# %%
import matplotlib.pyplot as plt
x=[10,20,30,40,50]
y=[29,10,20,39,33]
plt.xlabel('overs')
plt.ylabel('runs scored')
plt.title('over wise runs scored\n inida vs england')
plt.plot(x,y,'c',linewidth=4,linestyle='dashed')
plt.show()

# %%
import matplotlib.pyplot as plt
x=[10,20,30,40,50]
y=[29,10,20,39,33]
plt.xlabel('overs')
plt.ylabel('runs scored')
plt.title('over wise runs scored\n inida vs england')
plt.plot(x,y,'y',linewidth=4,linestyle='dashed')
plt.show()

# %%
import matplotlib.pyplot as plt
x=[10,20,30,40,50]
y=[29,10,20,39,33]
plt.xlabel('overs')
plt.ylabel('runs scored')
plt.title('over wise runs scored\n inida vs england')
plt.plot(x,y,'g',linewidth=4,linestyle='dashed')
plt.show()

# %%
import matplotlib.pyplot as plt
x=[10,20,30,40,50]
y=[29,10,20,39,33]
a=[14,29,34,10,29]
b=[29,34,56,78,32]
plt.xlabel('overs')
plt.ylabel('runs scored')
plt.title('over wise runs scored\n inida vs england')
plt.plot(x,y,'c',linewidth=4,linestyle='dashed')
plt.plot(a,b,'b',linewidth=4,linestyle='dashed')
plt.show()

# %%
import matplotlib.pyplot as plt
x=[10,20,30,40,50]
y=[29,10,20,39,33]
a=[14,29,34,10,29]
b=[29,34,56,78,32]
plt.xlabel('overs')
plt.ylabel('runs scored')
plt.title('over wise runs scored\n inida vs england')
plt.plot(x,y,'r',linewidth=4,linestyle='dashed')
plt.plot(a,b,'g',linewidth=4,linestyle='dashed')
plt.show()

# %%
import matplotlib.pyplot as plt
x=[10,20,30,40,50]
y=[29,39,49,59,69]
a=[10,20,30,40,50]
b=[12,23,34,45,56]
plt.xlabel('overs')
plt.ylabel('runs scored')
plt.title('over wise runs scored\n inida vs england')
plt.plot(x,y,'c',linewidth=4,linestyle='dashed')
plt.plot(a,b,'b',linewidth=4,linestyle='dashed')
plt.show()

# %%
import matplotlib.pyplot as plt
x=[10,20,30,40,50]
y=[29,39,49,59,69]
plt.xlabel('overs')
plt.ylabel('runs scored')
plt.title('over wise runs scored\n inida vs england')
plt.plot(x,y,marker='+',markersize='10',markeredgecolor='r')
plt.show()
